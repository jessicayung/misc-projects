# %% [markdown]
# # EPL vs ESL Speaks

# %% [markdown]
# ## 1 Import and Preprocess Data
#
# ### 1.1 Import data and delete unwanted datapoints
# 1. Copy speaker tabs from WUDC2017, EUDC2016, Oxford IV 2016, Cambridge IV 2016.
#
# 2. Remove speakers who have not completed all five rounds or are swing speakers from the tab.
#     * If speakers have not completed all five rounds, they may have been ill and so other confounding factors likely affected their performance.
#     * Swing speakers may not be  taking the tournament seriously. Their on-tab names may also be wrong.
#         * Took out Swing A in EUDC2016 for completeness even though
#     * The average speaks also tend to wrong in that they are an average across rounds-including-those-where-said-speaker-got-zero-speaks.
#
# ### 1.2 Convert data into desired format
# 1. Create dummy variable columns for EPL, ESL, EFL and ESL_or_EFL.
#     * EFL applies only to WUDC and EUDC.
#     * Distinguishing between ESL and EFL speakers may be of interest, so we will keep both categories and add an `ESL_or_EFL` dummy variable.
#     * Method: use formula `=IF(C2,1,0)`, for each cell in the `is_esl` column where column C is the speaker's ESL rank and 2 is the speaker's row number.
# 2. Create datasets:
#     * (i) Use average speaks in a tournament per speaker only.
#     *

# %%
import pandas as pd
from collections import defaultdict

# %%
# Read in tab data (with `is_esl` column)
eudc2016 = pd.read_csv("eudc2016.csv")
wudc2017 = pd.read_csv("wudc2017.csv")
oxiv2016 = pd.read_csv("oxiv2016.csv")
camiv2016 = pd.read_csv("camiv2016.csv")

# %%
# Preview one tab
eudc2016.head()
# Out:
#    is_esl  ENL  ESL                Speaker        Team  Team Points  \
# 0       0    1  NaN  Michael Dunn Goekjian       PEP A           22
# 1       1    2  1.0              Dan Lahav  Tel Aviv A           19
# 2       0    3  NaN             Kit Mercer    Durham A           23
# 3       0    3  NaN          Joshua Bailey    Durham A           23
# 4       0    5  NaN         Daniel Bramble       LSE A           21
#
#    Speaker Points   AVG  #1  #2  #3  #4  #5  #6  #7  #8  #9
# 0             762  84.7  87  83  84  85  86  87  84  84  82
# 1             759  84.3  86  84  82  86  85  81  83  91  81
# 2             753  83.7  83  85  82  85  80  82  83  85  88
# 3             753  83.7  84  85  82  83  82  83  83  85  86
# 4             749  83.2  79  85  83  81  82  85  86  83  85

# %%
# List the tabs we have for use in following code
list_of_tabs = [(wudc2017, "wudc2017"), (oxiv2016, "oxiv2016"), 
                (camiv2016, "camiv2016"),(eudc2016, "eudc2016")]

# %%
# Create a dictionary to store information
# defaultdict prevents KeyErrors
average_speaks_per_tournament = defaultdict(dict)

# Add average speaks and ESL status per speaker to our dictionary
for tournament in list_of_tabs:
    # Unpack tuple values
    tournament_name = tournament[1]
    tournament_tab = tournament[0]
    for row_index in range(len(tournament_tab)):
        row = tournament_tab.loc[row_index]
        speaker_name = row['Speaker']
        speaker_average = row['AVG']
        # Add tournament speaks average to speaker record
        speaker_record = average_speaks_per_tournament[speaker_name]
        speaker_record[tournament_name + "_avg"] = speaker_average
        # Add is_esl to speaker record
        speaker_record['is_esl_' + tournament_name] = row['is_esl']

# %%
# View dictionary 
# to check it's approx what we expect
average_speaks_per_tournament
# Out:
# defaultdict(dict,
#             {'Nicholas Salmon': {'is_esl_wudc2017': 0,
#               'wudc2017_avg': 80

#               'is_esl_camiv2016': 0,
#               'is_esl_oxiv2016': 0,
#               'is_esl_wudc2017': 0,
#               'oxiv2016_avg': 76.400000000000006,
#               'wudc2017_avg': 77.599999999999994},
#              'Maria Epishkina': {'eudc2016_avg': 75.0, 'is_esl_eudc2016': 0},
#              'Anneliese Cooper': {'is_esl_wudc2017': 0,
#               'wudc2017_avg': 74.400000000000006},
#              'Izzat Arif': {'camiv2016_avg': 78.400000000000006,
#               'is_esl_camiv2016': 0,
#               'is_esl_oxiv2016': 0,
#               'is_esl_wudc2017': 0,
#               'oxiv2016_avg': 76.799999999999997,
#               'wudc2017_avg': 77.299999999999997},
#              'Laura Smith': {'eudc2016_avg': 77.400000000000006,
#               'is_esl_eudc2016': 0},
#              'Ellie Shearer': {'eudc2016_avg': 81.099999999999994,
#               'is_esl_eudc2016': 0},
#              'Stefan Torges': {'eudc2016_avg': 77.900000000000006,
#               'is_esl_eudc2016': 1},
#              ...})

# %%
# Combine all esl indicators using OR

# this doesn't work! :(
# TODO: Fix this. For now am doing this in Google Sheets instead.
for speaker in average_speaks_per_tournament:
    # Should not hard code this but I'm lazy
    speaker['is_esl'] = speaker['is_esl_eudc2016'] \
                        or speaker['is_esl_wudc2017'] \
                        or speaker['is_esl_oxiv2016'] \
                        or speaker['is_esl_camiv2016']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-9ed0260332b8> in <module>()
#       2 for speaker in average_speaks_per_tournament:
#       3     # Should not hard code this but I'm lazy
# ----> 4     speaker['is_esl'] = speaker['is_esl_eudc2016']                         or speaker['is_esl_wudc2017']                         or speaker['is_esl_oxiv2016']                         or speaker['is_esl_camiv2016']
#
# TypeError: string indices must be integers

# %%
# Convert dictionary to a dataframe to export
average_speaks_per_tournament_df = \
    pd.DataFrame.from_dict(average_speaks_per_tournament, orient="index")

# %%
# View dataframe to check it's what we expect
average_speaks_per_tournament_df
# Out:
#                                  is_esl_wudc2017  wudc2017_avg  eudc2016_avg  \
# ABEL LAW                                     NaN           NaN           NaN
# Aaron Luke                                   0.0          80.6           NaN
# Aaron Schaffer-Neitz                         0.0          77.2           NaN
# Abhi Kulgod                                  0.0          76.2           NaN
# Abhik Pant                                   1.0          70.1           NaN
# Abhiroop Lohia                               NaN           NaN           NaN
# Abhisheka Dubey                              0.0          78.2           NaN
# Abigail Westberry                            0.0          76.6           NaN
# Abu Saleh Didar                              1.0          77.1           NaN
# Acca Kwai Ching Sum                          1.0          76.1           NaN
# Adam Stairs                                  0.0          79.7          77.3
# Adela Lilollari Adela Lilollari              0.0          78.1           NaN
# Adenike McDonald                             0.0          71.4           NaN
# Adil Abdulla                                 0.0          75.9           NaN
# Aditya Vaibhav Gupta                         1.0          74.8           NaN
# Agnes Putri                                  1.0          74.8           NaN
# Ahmed Naufal                                 1.0          78.3           NaN
# Aidan Patrick                                0.0          78.7          78.1
# Aigerim Shadeyeva                            1.0          74.0           NaN
# Aiken Nuraly                                 NaN           NaN          72.1
# Aino Tuohimaa                                1.0          72.1           NaN
# Aion Feehan                                  0.0          74.4          73.8
# Aishling Kinsella                            NaN           NaN           NaN
# Aislin Flynn                                 0.0          82.6           NaN
# Aisling Tully                                0.0          76.7          79.6
# Ajinkya Deshpande                            0.0          78.7           NaN
# Akeela Marin                                 0.0          72.9           NaN
# Alaaeldin Elsayed                            0.0          70.8           NaN
# Alan Chan                                    0.0          77.8           NaN
# Alan Hickey                                  NaN           NaN          76.8
# ...                                          ...           ...           ...
# Yosifebi Ramadhani                           1.0          74.2           NaN
# Yuji Masumura                                1.0          68.8           NaN
# Yuki Kono                                    1.0          69.3           NaN
# Yuliyana Georgieva                           NaN           NaN          69.7
# Yuna Wang                                    NaN           NaN          74.4
# ZHANG Bo wen                                 1.0          70.8           NaN
# Zachary Lemonides                            0.0          75.1           NaN
# Zeno Glastra van Loon                        1.0          74.1           NaN
# Zeynep Arat                                  NaN           NaN          67.7
# Zhen Huang                                   0.0          80.6           NaN
# Zhengqi Zhu                                  1.0          75.3           NaN
# Zhixuan Wang                                 NaN           NaN           NaN
# Zoe Brown                                    0.0          80.2           NaN
# Zoe Morgan                                   0.0          77.9           NaN
# Zoe Sandle                                   1.0          75.4           NaN
# Zoe Seaman-Grant                             0.0          81.3           NaN
# Zola Valashiya                               0.0          75.9           NaN
# Zoran Fijavž                                 NaN           NaN          74.2
# Zulfaqqar Asyraf bin Marzuki                 0.0          70.9           NaN
# Zvonimir Kuzmanic                            1.0          73.3           NaN
# itay __Nourian                               NaN           NaN          73.1
# jihyeon bae                                  1.0          74.6           NaN
# kasumi Nogawa                                1.0          73.9           NaN
# louis honee                                  1.0          75.2           NaN
# sibulele ngozi                               0.0          70.9           NaN
# Álvaro Ortega                                1.0          71.7           NaN
# Đorđe Jovićević                              1.0          79.7           NaN
# İhsan Can Argon                              NaN           NaN          72.1
# Łukasz Bartoszcze                            1.0          73.8          73.3
# Žygimantas Marcinkevičius                    NaN           NaN           NaN
#
#                                  is_esl_eudc2016  oxiv2016_avg  \
# ABEL LAW                                     NaN          77.2
# Aaron Luke                                   NaN          77.0
# Aaron Schaffer-Neitz                         NaN          75.4
# Abhi Kulgod                                  NaN           NaN
# Abhik Pant                                   NaN           NaN
# Abhiroop Lohia                               NaN           NaN
# Abhisheka Dubey                              NaN           NaN
# Abigail Westberry                            NaN          78.2
# Abu Saleh Didar                              NaN           NaN
# Acca Kwai Ching Sum                          NaN           NaN
# Adam Stairs                                  0.0          79.0
# Adela Lilollari Adela Lilollari              NaN           NaN
# Adenike McDonald                             NaN           NaN
# Adil Abdulla                                 NaN           NaN
# Aditya Vaibhav Gupta                         NaN           NaN
# Agnes Putri                                  NaN           NaN
# Ahmed Naufal                                 NaN           NaN
# Aidan Patrick                                0.0          79.0
# Aigerim Shadeyeva                            NaN           NaN
# Aiken Nuraly                                 1.0           NaN
# Aino Tuohimaa                                NaN           NaN
# Aion Feehan                                  0.0          73.0
# Aishling Kinsella                            NaN          76.6
# Aislin Flynn                                 NaN          81.2
# Aisling Tully                                0.0           NaN
# Ajinkya Deshpande                            NaN           NaN
# Akeela Marin                                 NaN           NaN
# Alaaeldin Elsayed                            NaN           NaN
# Alan Chan                                    NaN           NaN
# Alan Hickey                                  0.0           NaN
# ...                                          ...           ...
# Yosifebi Ramadhani                           NaN           NaN
# Yuji Masumura                                NaN           NaN
# Yuki Kono                                    NaN           NaN
# Yuliyana Georgieva                           1.0           NaN
# Yuna Wang                                    0.0           NaN
# ZHANG Bo wen                                 NaN           NaN
# Zachary Lemonides                            NaN           NaN
# Zeno Glastra van Loon                        NaN           NaN
# Zeynep Arat                                  1.0           NaN
# Zhen Huang                                   NaN           NaN
# Zhengqi Zhu                                  NaN           NaN
# Zhixuan Wang                                 NaN          71.0
# Zoe Brown                                    NaN           NaN
# Zoe Morgan                                   NaN           NaN
# Zoe Sandle                                   NaN           NaN
# Zoe Seaman-Grant                             NaN           NaN
# Zola Valashiya                               NaN           NaN
# Zoran Fijavž                                 1.0           NaN
# Zulfaqqar Asyraf bin Marzuki                 NaN           NaN
# Zvonimir Kuzmanic                            NaN           NaN
# itay __Nourian                               1.0           NaN
# jihyeon bae                                  NaN           NaN
# kasumi Nogawa                                NaN           NaN
# louis honee                                  NaN           NaN
# sibulele ngozi                               NaN           NaN
# Álvaro Ortega                                NaN           NaN
# Đorđe Jovićević                              NaN          80.0
# İhsan Can Argon                              1.0           NaN
# Łukasz Bartoszcze                            1.0           NaN
# Žygimantas Marcinkevičius                    NaN           NaN
#
#                                  is_esl_oxiv2016  is_esl_camiv2016  \
# ABEL LAW                                     1.0               NaN
# Aaron Luke                                   0.0               0.0
# Aaron Schaffer-Neitz                         0.0               0.0
# Abhi Kulgod                                  NaN               NaN
# Abhik Pant                                   NaN               NaN
# Abhiroop Lohia                               NaN               0.0
# Abhisheka Dubey                              NaN               NaN
# Abigail Westberry                            0.0               NaN
# Abu Saleh Didar                              NaN               NaN
# Acca Kwai Ching Sum                          NaN               NaN
# Adam Stairs                                  0.0               0.0
# Adela Lilollari Adela Lilollari              NaN               NaN
# Adenike McDonald                             NaN               NaN
# Adil Abdulla                                 NaN               NaN
# Aditya Vaibhav Gupta                         NaN               NaN
# Agnes Putri                                  NaN               1.0
# Ahmed Naufal                                 NaN               NaN
# Aidan Patrick                                0.0               NaN
# Aigerim Shadeyeva                            NaN               NaN
# Aiken Nuraly                                 NaN               NaN
# Aino Tuohimaa                                NaN               NaN
# Aion Feehan                                  0.0               NaN
# Aishling Kinsella                            0.0               NaN
# Aislin Flynn                                 0.0               0.0
# Aisling Tully                                NaN               0.0
# Ajinkya Deshpande                            NaN               NaN
# Akeela Marin                                 NaN               NaN
# Alaaeldin Elsayed                            NaN               NaN
# Alan Chan                                    NaN               NaN
# Alan Hickey                                  NaN               NaN
# ...                                          ...               ...
# Yosifebi Ramadhani                           NaN               NaN
# Yuji Masumura                                NaN               NaN
# Yuki Kono                                    NaN               NaN
# Yuliyana Georgieva                           NaN               NaN
# Yuna Wang                                    NaN               NaN
# ZHANG Bo wen                                 NaN               NaN
# Zachary Lemonides                            NaN               NaN
# Zeno Glastra van Loon                        NaN               NaN
# Zeynep Arat                                  NaN               NaN
# Zhen Huang                                   NaN               0.0
# Zhengqi Zhu                                  NaN               NaN
# Zhixuan Wang                                 1.0               NaN
# Zoe Brown                                    NaN               NaN
# Zoe Morgan                                   NaN               NaN
# Zoe Sandle                                   NaN               NaN
# Zoe Seaman-Grant                             NaN               0.0
# Zola Valashiya                               NaN               NaN
# Zoran Fijavž                                 NaN               NaN
# Zulfaqqar Asyraf bin Marzuki                 NaN               NaN
# Zvonimir Kuzmanic                            NaN               NaN
# itay __Nourian                               NaN               NaN
# jihyeon bae                                  NaN               NaN
# kasumi Nogawa                                NaN               NaN
# louis honee                                  NaN               NaN
# sibulele ngozi                               NaN               NaN
# Álvaro Ortega                                NaN               NaN
# Đorđe Jovićević                              1.0               1.0
# İhsan Can Argon                              NaN               NaN
# Łukasz Bartoszcze                            NaN               NaN
# Žygimantas Marcinkevičius                    NaN               0.0
#
#                                  camiv2016_avg
# ABEL LAW                                   NaN
# Aaron Luke                                78.2
# Aaron Schaffer-Neitz                      76.6
# Abhi Kulgod                                NaN
# Abhik Pant                                 NaN
# Abhiroop Lohia                            76.4
# Abhisheka Dubey                            NaN
# Abigail Westberry                          NaN
# Abu Saleh Didar                            NaN
# Acca Kwai Ching Sum                        NaN
# Adam Stairs                               79.2
# Adela Lilollari Adela Lilollari            NaN
# Adenike McDonald                           NaN
# Adil Abdulla                               NaN
# Aditya Vaibhav Gupta                       NaN
# Agnes Putri                               73.4
# Ahmed Naufal                               NaN
# Aidan Patrick                              NaN
# Aigerim Shadeyeva                          NaN
# Aiken Nuraly                               NaN
# Aino Tuohimaa                              NaN
# Aion Feehan                                NaN
# Aishling Kinsella                          NaN
# Aislin Flynn                              80.2
# Aisling Tully                             77.4
# Ajinkya Deshpande                          NaN
# Akeela Marin                               NaN
# Alaaeldin Elsayed                          NaN
# Alan Chan                                  NaN
# Alan Hickey                                NaN
# ...                                        ...
# Yosifebi Ramadhani                         NaN
# Yuji Masumura                              NaN
# Yuki Kono                                  NaN
# Yuliyana Georgieva                         NaN
# Yuna Wang                                  NaN
# ZHANG Bo wen                               NaN
# Zachary Lemonides                          NaN
# Zeno Glastra van Loon                      NaN
# Zeynep Arat                                NaN
# Zhen Huang                                80.8
# Zhengqi Zhu                                NaN
# Zhixuan Wang                               NaN
# Zoe Brown                                  NaN
# Zoe Morgan                                 NaN
# Zoe Sandle                                 NaN
# Zoe Seaman-Grant                          81.2
# Zola Valashiya                             NaN
# Zoran Fijavž                               NaN
# Zulfaqqar Asyraf bin Marzuki               NaN
# Zvonimir Kuzmanic                          NaN
# itay __Nourian                             NaN
# jihyeon bae                                NaN
# kasumi Nogawa                              NaN
# louis honee                                NaN
# sibulele ngozi                             NaN
# Álvaro Ortega                              NaN
# Đorđe Jovićević                           79.0
# İhsan Can Argon                            NaN
# Łukasz Bartoszcze                          NaN
# Žygimantas Marcinkevičius                 70.2
#
# [1230 rows x 8 columns]

# %%
# Attempt to combine ESL indicators again
# and fail again :(
for row_index in range(len(average_speaks_per_tournament_df)):
    row = average_speaks_per_tournament_df.iloc[row_index]
    row['is_esl'] = row['is_esl_wudc2017'] or row['is_esl_oxiv2016'] \
                    or row['is_esl_camiv2016'] or row['is_esl_eudc2016']

# %%
# View df again: combining ESL indicators is still not working!
average_speaks_per_tournament_df.head()
# Out:
#                                  is_esl_wudc2017  wudc2017_avg  eudc2016_avg  \
# ABEL LAW                                     NaN           NaN           NaN
# Aaron Luke                                   0.0          80.6           NaN
# Aaron Schaffer-Neitz                         0.0          77.2           NaN
# Abhi Kulgod                                  0.0          76.2           NaN
# Abhik Pant                                   1.0          70.1           NaN
# Abhiroop Lohia                               NaN           NaN           NaN
# Abhisheka Dubey                              0.0          78.2           NaN
# Abigail Westberry                            0.0          76.6           NaN
# Abu Saleh Didar                              1.0          77.1           NaN
# Acca Kwai Ching Sum                          1.0          76.1           NaN
# Adam Stairs                                  0.0          79.7          77.3
# Adela Lilollari Adela Lilollari              0.0          78.1           NaN
# Adenike McDonald                             0.0          71.4           NaN
# Adil Abdulla                                 0.0          75.9           NaN
# Aditya Vaibhav Gupta                         1.0          74.8           NaN
# Agnes Putri                                  1.0          74.8           NaN
# Ahmed Naufal                                 1.0          78.3           NaN
# Aidan Patrick                                0.0          78.7          78.1
# Aigerim Shadeyeva                            1.0          74.0           NaN
# Aiken Nuraly                                 NaN           NaN          72.1
# Aino Tuohimaa                                1.0          72.1           NaN
# Aion Feehan                                  0.0          74.4          73.8
# Aishling Kinsella                            NaN           NaN           NaN
# Aislin Flynn                                 0.0          82.6           NaN
# Aisling Tully                                0.0          76.7          79.6
# Ajinkya Deshpande                            0.0          78.7           NaN
# Akeela Marin                                 0.0          72.9           NaN
# Alaaeldin Elsayed                            0.0          70.8           NaN
# Alan Chan                                    0.0          77.8           NaN
# Alan Hickey                                  NaN           NaN          76.8
# ...                                          ...           ...           ...
# Yosifebi Ramadhani                           1.0          74.2           NaN
# Yuji Masumura                                1.0          68.8           NaN
# Yuki Kono                                    1.0          69.3           NaN
# Yuliyana Georgieva                           NaN           NaN          69.7
# Yuna Wang                                    NaN           NaN          74.4
# ZHANG Bo wen                                 1.0          70.8           NaN
# Zachary Lemonides                            0.0          75.1           NaN
# Zeno Glastra van Loon                        1.0          74.1           NaN
# Zeynep Arat                                  NaN           NaN          67.7
# Zhen Huang                                   0.0          80.6           NaN
# Zhengqi Zhu                                  1.0          75.3           NaN
# Zhixuan Wang                                 NaN           NaN           NaN
# Zoe Brown                                    0.0          80.2           NaN
# Zoe Morgan                                   0.0          77.9           NaN
# Zoe Sandle                                   1.0          75.4           NaN
# Zoe Seaman-Grant                             0.0          81.3           NaN
# Zola Valashiya                               0.0          75.9           NaN
# Zoran Fijavž                                 NaN           NaN          74.2
# Zulfaqqar Asyraf bin Marzuki                 0.0          70.9           NaN
# Zvonimir Kuzmanic                            1.0          73.3           NaN
# itay __Nourian                               NaN           NaN          73.1
# jihyeon bae                                  1.0          74.6           NaN
# kasumi Nogawa                                1.0          73.9           NaN
# louis honee                                  1.0          75.2           NaN
# sibulele ngozi                               0.0          70.9           NaN
# Álvaro Ortega                                1.0          71.7           NaN
# Đorđe Jovićević                              1.0          79.7           NaN
# İhsan Can Argon                              NaN           NaN          72.1
# Łukasz Bartoszcze                            1.0          73.8          73.3
# Žygimantas Marcinkevičius                    NaN           NaN           NaN
#
#                                  is_esl_eudc2016  oxiv2016_avg  \
# ABEL LAW                                     NaN          77.2
# Aaron Luke                                   NaN          77.0
# Aaron Schaffer-Neitz                         NaN          75.4
# Abhi Kulgod                                  NaN           NaN
# Abhik Pant                                   NaN           NaN
# Abhiroop Lohia                               NaN           NaN
# Abhisheka Dubey                              NaN           NaN
# Abigail Westberry                            NaN          78.2
# Abu Saleh Didar                              NaN           NaN
# Acca Kwai Ching Sum                          NaN           NaN
# Adam Stairs                                  0.0          79.0
# Adela Lilollari Adela Lilollari              NaN           NaN
# Adenike McDonald                             NaN           NaN
# Adil Abdulla                                 NaN           NaN
# Aditya Vaibhav Gupta                         NaN           NaN
# Agnes Putri                                  NaN           NaN
# Ahmed Naufal                                 NaN           NaN
# Aidan Patrick                                0.0          79.0
# Aigerim Shadeyeva                            NaN           NaN
# Aiken Nuraly                                 1.0           NaN
# Aino Tuohimaa                                NaN           NaN
# Aion Feehan                                  0.0          73.0
# Aishling Kinsella                            NaN          76.6
# Aislin Flynn                                 NaN          81.2
# Aisling Tully                                0.0           NaN
# Ajinkya Deshpande                            NaN           NaN
# Akeela Marin                                 NaN           NaN
# Alaaeldin Elsayed                            NaN           NaN
# Alan Chan                                    NaN           NaN
# Alan Hickey                                  0.0           NaN
# ...                                          ...           ...
# Yosifebi Ramadhani                           NaN           NaN
# Yuji Masumura                                NaN           NaN
# Yuki Kono                                    NaN           NaN
# Yuliyana Georgieva                           1.0           NaN
# Yuna Wang                                    0.0           NaN
# ZHANG Bo wen                                 NaN           NaN
# Zachary Lemonides                            NaN           NaN
# Zeno Glastra van Loon                        NaN           NaN
# Zeynep Arat                                  1.0           NaN
# Zhen Huang                                   NaN           NaN
# Zhengqi Zhu                                  NaN           NaN
# Zhixuan Wang                                 NaN          71.0
# Zoe Brown                                    NaN           NaN
# Zoe Morgan                                   NaN           NaN
# Zoe Sandle                                   NaN           NaN
# Zoe Seaman-Grant                             NaN           NaN
# Zola Valashiya                               NaN           NaN
# Zoran Fijavž                                 1.0           NaN
# Zulfaqqar Asyraf bin Marzuki                 NaN           NaN
# Zvonimir Kuzmanic                            NaN           NaN
# itay __Nourian                               1.0           NaN
# jihyeon bae                                  NaN           NaN
# kasumi Nogawa                                NaN           NaN
# louis honee                                  NaN           NaN
# sibulele ngozi                               NaN           NaN
# Álvaro Ortega                                NaN           NaN
# Đorđe Jovićević                              NaN          80.0
# İhsan Can Argon                              1.0           NaN
# Łukasz Bartoszcze                            1.0           NaN
# Žygimantas Marcinkevičius                    NaN           NaN
#
#                                  is_esl_oxiv2016  is_esl_camiv2016  \
# ABEL LAW                                     1.0               NaN
# Aaron Luke                                   0.0               0.0
# Aaron Schaffer-Neitz                         0.0               0.0
# Abhi Kulgod                                  NaN               NaN
# Abhik Pant                                   NaN               NaN
# Abhiroop Lohia                               NaN               0.0
# Abhisheka Dubey                              NaN               NaN
# Abigail Westberry                            0.0               NaN
# Abu Saleh Didar                              NaN               NaN
# Acca Kwai Ching Sum                          NaN               NaN
# Adam Stairs                                  0.0               0.0
# Adela Lilollari Adela Lilollari              NaN               NaN
# Adenike McDonald                             NaN               NaN
# Adil Abdulla                                 NaN               NaN
# Aditya Vaibhav Gupta                         NaN               NaN
# Agnes Putri                                  NaN               1.0
# Ahmed Naufal                                 NaN               NaN
# Aidan Patrick                                0.0               NaN
# Aigerim Shadeyeva                            NaN               NaN
# Aiken Nuraly                                 NaN               NaN
# Aino Tuohimaa                                NaN               NaN
# Aion Feehan                                  0.0               NaN
# Aishling Kinsella                            0.0               NaN
# Aislin Flynn                                 0.0               0.0
# Aisling Tully                                NaN               0.0
# Ajinkya Deshpande                            NaN               NaN
# Akeela Marin                                 NaN               NaN
# Alaaeldin Elsayed                            NaN               NaN
# Alan Chan                                    NaN               NaN
# Alan Hickey                                  NaN               NaN
# ...                                          ...               ...
# Yosifebi Ramadhani                           NaN               NaN
# Yuji Masumura                                NaN               NaN
# Yuki Kono                                    NaN               NaN
# Yuliyana Georgieva                           NaN               NaN
# Yuna Wang                                    NaN               NaN
# ZHANG Bo wen                                 NaN               NaN
# Zachary Lemonides                            NaN               NaN
# Zeno Glastra van Loon                        NaN               NaN
# Zeynep Arat                                  NaN               NaN
# Zhen Huang                                   NaN               0.0
# Zhengqi Zhu                                  NaN               NaN
# Zhixuan Wang                                 1.0               NaN
# Zoe Brown                                    NaN               NaN
# Zoe Morgan                                   NaN               NaN
# Zoe Sandle                                   NaN               NaN
# Zoe Seaman-Grant                             NaN               0.0
# Zola Valashiya                               NaN               NaN
# Zoran Fijavž                                 NaN               NaN
# Zulfaqqar Asyraf bin Marzuki                 NaN               NaN
# Zvonimir Kuzmanic                            NaN               NaN
# itay __Nourian                               NaN               NaN
# jihyeon bae                                  NaN               NaN
# kasumi Nogawa                                NaN               NaN
# louis honee                                  NaN               NaN
# sibulele ngozi                               NaN               NaN
# Álvaro Ortega                                NaN               NaN
# Đorđe Jovićević                              1.0               1.0
# İhsan Can Argon                              NaN               NaN
# Łukasz Bartoszcze                            NaN               NaN
# Žygimantas Marcinkevičius                    NaN               0.0
#
#                                  camiv2016_avg
# ABEL LAW                                   NaN
# Aaron Luke                                78.2
# Aaron Schaffer-Neitz                      76.6
# Abhi Kulgod                                NaN
# Abhik Pant                                 NaN
# Abhiroop Lohia                            76.4
# Abhisheka Dubey                            NaN
# Abigail Westberry                          NaN
# Abu Saleh Didar                            NaN
# Acca Kwai Ching Sum                        NaN
# Adam Stairs                               79.2
# Adela Lilollari Adela Lilollari            NaN
# Adenike McDonald                           NaN
# Adil Abdulla                               NaN
# Aditya Vaibhav Gupta                       NaN
# Agnes Putri                               73.4
# Ahmed Naufal                               NaN
# Aidan Patrick                              NaN
# Aigerim Shadeyeva                          NaN
# Aiken Nuraly                               NaN
# Aino Tuohimaa                              NaN
# Aion Feehan                                NaN
# Aishling Kinsella                          NaN
# Aislin Flynn                              80.2
# Aisling Tully                             77.4
# Ajinkya Deshpande                          NaN
# Akeela Marin                               NaN
# Alaaeldin Elsayed                          NaN
# Alan Chan                                  NaN
# Alan Hickey                                NaN
# ...                                        ...
# Yosifebi Ramadhani                         NaN
# Yuji Masumura                              NaN
# Yuki Kono                                  NaN
# Yuliyana Georgieva                         NaN
# Yuna Wang                                  NaN
# ZHANG Bo wen                               NaN
# Zachary Lemonides                          NaN
# Zeno Glastra van Loon                      NaN
# Zeynep Arat                                NaN
# Zhen Huang                                80.8
# Zhengqi Zhu                                NaN
# Zhixuan Wang                               NaN
# Zoe Brown                                  NaN
# Zoe Morgan                                 NaN
# Zoe Sandle                                 NaN
# Zoe Seaman-Grant                          81.2
# Zola Valashiya                             NaN
# Zoran Fijavž                               NaN
# Zulfaqqar Asyraf bin Marzuki               NaN
# Zvonimir Kuzmanic                          NaN
# itay __Nourian                             NaN
# jihyeon bae                                NaN
# kasumi Nogawa                              NaN
# louis honee                                NaN
# sibulele ngozi                             NaN
# Álvaro Ortega                              NaN
# Đorđe Jovićević                           79.0
# İhsan Can Argon                            NaN
# Łukasz Bartoszcze                          NaN
# Žygimantas Marcinkevičius                 70.2
#
# [1230 rows x 8 columns]

# %%
# Convert the dataframe to a CSV 
# because I'm lazy and want to manipulate data in Google Sheets 
# and then run regs in Stata
average_speaks_per_tournament_df.to_csv(path_or_buf="avg_speaks_per_tournament_no_combined_esl_status.csv")

# %% [markdown]
# Deprecated code:
# ```
# if speaker_record['is_esl'] is None or speaker_record['is_esl'] == 0:
#             speaker_record['is_esl'] = row['is_esl']
# ```
# Returns
# ```
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-15a25a89b6b3> in <module>()
#      10         speaker_record = average_speaks_per_tournament[speaker_name]
#      11         speaker_record[tournament_name + "_avg"] = speaker_average
# ---> 12         if speaker_record['is_esl'] is None or speaker_record['is_esl'] == 0:
#      13             speaker_record['is_esl'] = row['is_esl']
#
# KeyError: 'is_esl'
# ```

# %% [markdown]
# ## Suggestions
# ### Things to do suggestions
# * Add dummy variables `top_quartile`, `bottom_quartile` or similar to see if ESL bias 'increases down the tab'.
#     * May have issues with interpreting the coefficients
# * Factoring in name or institutional recognition (though this probably doesn't affected ESL speakers exclusively or more than EPL speakers so it seems more appropriate for a separate study. And presumably effects apply across all tournaments so *shrugs*.)
# * Region chairs are from
# * Region speakers are from
# * Identify where the drop in average speaks comes from (drop in speaker's highest speaks or lowest or across the board)
#     * Hypothesis that bad speeches are judged more harshly at Oxbridge IVs (Roel Becker)
# * Over-representation of high scoring speakers at Oxbridge (meh)
#     * this will only matter in so far as it pulls up speaks in general since we're comparing an individual's speaks at WUDC vs Oxbridge IVs.
# * Having judges who regularly judge certain ESL speakers and give them high speaks may make it easier for those judges to give 86s and 85s rather than 82s. (Berman)
#     * Okay I don't see an easy way of correcting for this, also likely applies to both ESL and EPL?
#
# ### Method based suggestions
# * Something two way ANOVA optionally with repeated measures
# * Separate judges willing to make use of the 85-90 range (Joe Roussos).
#     * If you look just at a small sample of teams (those that the top 15 speakers were in, say) then you're vulnerable to the confounding effect of encountering high-scoring judges more frequently at Cambridge, vs. at Worlds.
#     * and Effect of CA teams having different allocation strategies
#         * In general WUDC seems to have allocated higher ranked judges closer to the middle of the tab than Cambridge's more manual system
#             * and proportion of ESL teams in top rooms may have been different (Berman)
#                 * This is valid only if for each ESL speaker, they are more likely to have been in a room with a high-speak-giving judge in Cam/Ox IV than not, and this effect is significantly different than for EPL speakers (whose speaks we used).
#     * How to test for this / correct for it:
#         1. Use Tabbie data across tournaments to track the kinds of scores judges give. Compare how judge A ranks a speaker, compared to the average speaks they get. In this way you can test my hypothesis and, if correct, identify the high scorers for step 2.
#
#         2. Correct for relative differences in contact with high scorers in your regression. Ideal comparison points are those with similar contact across all competitions tested.

# %% [markdown]
# The horrific Berman x Simpson thread
